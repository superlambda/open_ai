# %%
from transformers import pipeline
classifier = pipeline(task="sentiment-analysis", device=-1)
preds = classifier("I am really happy today!")
print(preds)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9998762607574463}]

# %%
from transformers import pipeline
transcriber = pipeline(model="openai/whisper-medium", device=0)
result = transcriber("./data/podcast_clip.mp3")
print(result)

# %%
import os, requests, json
API_TOKEN = os.environ.get("HUGGINGFACE_API_KEY")
model = "google/flan-t5-xxl"
API_URL = f"https://api-inference.huggingface.co/models/{model}"
headers = {"Authorization": f"Bearer {API_TOKEN}", "Content-Type": "application/json"}
def query(payload, api_url=API_URL, headers=headers):
    data = json.dumps(payload)
    response = requests.request("POST", api_url, headers=headers, data=data)
    return json.loads(response.content.decode("utf-8"))
question = "Please answer the following question. What is the capital of France?"
data = query({"inputs" : question, "wait_for_model" : True})
print(data)
# Out:
# {'error': 'Model google/flan-t5-xxl is currently loading', 'estimated_time': 1802.7086181640625}

# %%
API_URL = "https://mrtm1eu40mrfrg1a.us-east-1.aws.endpoints.huggingface.cloud"
text = "My name is Lewis and I like to"
data = query({"inputs" : text}, api_url=API_URL)
print(data)
# Out:
# [{'generated_text': 'My name is Lewis and I like to think of myself as a sports and social explorer … I\'ve been doing this since my early childhood, I\'ve been at it since college," says Lewis. "I\'m a big advocate of community organizing, and'}]
